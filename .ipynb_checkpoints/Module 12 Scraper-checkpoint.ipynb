# %%
from lxml import html, etree
import requests
import bs4 as bs

url = 'https://www.dmacc.edu/schedule/Pages/result.aspx?Term=202001&Campus=1&Subject=CIS&CourseNumber=CIS189'
response = requests.get(url)
print (response.text)
#html = response.content
#print(html)
#with open("requestResult.txt","w+") as file:
#    file.writelines(str(html))
#tree = html.fromstring(html.content)
#print(tree.text)
#soup = bs.BeautifulSoup(open("requestResult.txt"), 'html.parser')
#print(soup.prettify())
#print(tree.xpath("body"))
#for element in tree.xpath("//div[@class='*']"):
    #print(element.text)
    #print (etree.tostring(element))

# %%
import requests
import bs4 as bs

url = 'https://www.iowa-demographics.com/counties_by_population'
response = requests.get(url)

soup = bs.BeautifulSoup(response.text, 'html.parser')
#links = soup.find_all("a")
#print(links)
links = soup.find_all("table")
#print(links)
header = soup.find_all("th")
print (header)
rows = soup.find_all("tr")
print (rows)

# %%
from pprint import pprint

import pandas as pd

df = pd.read_html('view-source:https://www.iowa-demographics.com/counties_by_population',attrs={'class':'ranklist'})[0]  # get the first parsed dataframe

# %%
#simple import
import csv

with open('Iowa 2010 Census Data Population Income.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(row)
            line_count += 1
    print (f'processed {line_count} rows')
# Out:
# Column names are Rank, County, Per capita income, Median household income, Median Family Income, Population, Number of households
# ['1', 'Dallas', '$33,051 ', '$67,037 ', '$84,018 ', '66,135', '25,240']
# ['2', 'Dickinson', '$29,459 ', '$50,174 ', '$59,648 ', '16,667', '7,554']
# ['3', 'Polk', '$29,246 ', '$56,094 ', '$70,445 ', '430,640', '170,197']
# ['4', 'Warren', '$28,798 ', '$62,034 ', '$74,042 ', '46,225', '17,262']
# ['5', 'Linn', '$28,239 ', '$53,674 ', '$69,250 ', '211,226', '86,134']
# ['6', 'Plymouth', '$28,060 ', '$56,379 ', '$69,261 ', '24,986', '9,875']
# ['7', 'Johnson', '$28,008 ', '$51,380 ', '$74,547 ', '130,882', '52,715']
# ['8', 'Kossuth', '$27,415 ', '$48,277 ', '$61,012 ', '15,543', '6,697']
# ['9', 'Scott', '$27,408 ', '$49,964 ', '$64,513 ', '165,224', '66,765']
# ['', 'United States', '$27,334 ', '$51,914 ', '$62,982 ', '308,745,538', '116,716,292']
# ['10', 'Worth', '$27,240 ', '$49,673 ', '$56,659 ', '7,598', '3,172']
# ['11', 'Grundy', '$26,916 ', '$56,184 ', '$68,151 ', '12,453', '5,131']
# ['12', 'Iowa County', '$26,721 ', '$56,053 ', '$64,578 ', '16,355', '6,677']
# ['13', 'Guthrie', '$26,590 ', '$50,090 ', '$61,951 ', '10,954', '4,544']
# ['14', 'Bremer', '$26,522 ', '$55,676 ', '$68,602 ', '24,276', '9,385']
# ['15', 'Boone', '$25,998 ', '$49,578 ', '$66,872 ', '26,306', '10,728']
# ['16', 'Madison', '$25,711 ', '$53,183 ', '$67,099 ', '15,679', '6,025']
# ['17', 'Cerro Gordo', '$25,463 ', '$44,741 ', '$60,148 ', '44,151', '19,350']
# ['18', 'Story', '$25,450 ', '$48,248 ', '$74,278 ', '89,542', '34,736']
# ['19', 'Mills', '$25,400 ', '$59,481 ', '$73,532 ', '15,059', '5,605']
# ['20', 'Clay', '$25,398 ', '$43,542 ', '$56,460 ', '16,667', '7,282']
# ['', 'Iowa State', '$25,335 ', '$48,872 ', '$61,804 ', '3,046,355', '1,221,576']
# ['21', 'Poweshiek', '$25,218 ', '$50,998 ', '$65,744 ', '18,914', '7,555']
# ['22', 'Benton', '$25,111 ', '$54,726 ', '$64,970 ', '26,076', '10,302']
# ['23', 'Carroll', '$25,094 ', '$47,507 ', '$61,960 ', '20,816', '8,683']
# ['24', 'Dubuque', '$25,045 ', '$48,573 ', '$61,138 ', '93,653', '36,815']
# ['25', "O'Brien", '$24,771 ', '$44,018 ', '$59,391 ', '14,398', '6,069']
# ['26', 'Hamilton', '$24,765 ', '$46,188 ', '$61,472 ', '15,673', '6,540']
# ['27', 'Cedar', '$24,742 ', '$54,321 ', '$63,893 ', '18,499', '7,511']
# ['28', 'Marion', '$24,613 ', '$53,370 ', '$65,817 ', '33,309', '12,723']
# ['29', 'Humboldt', '$24,568 ', '$45,282 ', '$57,063 ', '9,815', '4,209']
# ['30', 'Cherokee', '$24,507 ', '$44,635 ', '$56,696 ', '12,072', '5,207']
# ['31', 'Emmet', '$24,371 ', '$42,286 ', '$55,844 ', '10,302', '4,236']
# ['32', 'Harrison', '$24,221 ', '$51,303 ', '$63,283 ', '14,928', '5,987']
# ['33', 'Audubon', '$24,207 ', '$42,717 ', '$58,641 ', '6,119', '2,617']
# ['34', 'Hardin', '$24,154 ', '$44,694 ', '$57,612 ', '17,534', '7,296']
# ['35', 'Muscatine', '$24,138 ', '$51,025 ', '$61,445 ', '42,745', '16,412']
# ['36', 'Butler', '$24,030 ', '$47,702 ', '$59,641 ', '14,867', '6,120']
# ['37', 'Washington', '$23,979 ', '$50,710 ', '$60,466 ', '21,704', '8,741']
# ['38', 'Greene', '$23,947 ', '$43,286 ', '$60,133 ', '9,336', '3,996']
# ['39', 'Jefferson', '$23,853 ', '$44,167 ', '$55,352 ', '16,843', '6,846']
# ['40', 'Ida', '$23,841 ', '$44,521 ', '$58,635 ', '7,089', '3,052']
# ['41', 'Sac', '$23,837 ', '$42,986 ', '$54,304 ', '10,350', '4,482']
# ['42', 'Pottawattamie', '$23,782 ', '$48,728 ', '$60,354 ', '93,158', '36,775']
# ['43', 'Fremont', '$23,612 ', '$47,225 ', '$59,622 ', '7,441', '3,064']
# ['44', 'Winneshiek', '$23,608 ', '$50,693 ', '$61,558 ', '21,056', '7,997']
# ['45', 'Clinton', '$23,573 ', '$46,170 ', '$58,681 ', '49,116', '20,223']
# ['46', 'Adams', '$23,549 ', '$40,368 ', '$52,782 ', '4,029', '1,715']
# ['47', 'Adair', '$23,497 ', '$45,202 ', '$57,287 ', '7,682', '3,292']
# ['48', 'Buchanan', '$23,437 ', '$51,961 ', '$61,421 ', '20,958', '8,161']
# ['49', 'Pocahontas', '$23,385 ', '$42,105 ', '$56,250 ', '7,310', '3,233']
# ['50', 'Black Hawk', '$23,357 ', '$44,178 ', '$57,495 ', '131,090', '52,470']
# ['51', 'Clarke', '$23,271 ', '$45,596 ', '$54,707 ', '9,286', '3,701']
# ['52', 'Jasper', '$23,160 ', '$46,396 ', '$56,484 ', '36,842', '14,806']
# ['53', 'Palo Alto', '$23,071 ', '$42,800 ', '$57,208 ', '9,421', '3,994']
# ['54', 'Wright', '$23,068 ', '$44,035 ', '$53,890 ', '13,229', '5,625']
# ['55', 'Osceola', '$23,063 ', '$43,889 ', '$58,286 ', '6,462', '2,682']
# ['56', 'Henry', '$23,056 ', '$41,983 ', '$53,985 ', '20,145', '7,666']
# ['57', 'Calhoun', '$23,049 ', '$41,611 ', '$50,037 ', '9,670', '4,242']
# ['58', 'Tama', '$23,041 ', '$46,288 ', '$55,011 ', '17,767', '6,947']
# ['59', 'Jackson', '$23,008 ', '$42,489 ', '$54,210 ', '19,848', '8,289']
# ['60', 'Jones', '$22,873 ', '$47,955 ', '$59,167 ', '20,638', '8,181']
# ['61', 'Mitchell', '$22,820 ', '$48,506 ', '$63,356 ', '10,776', '4,395']
# ['62', 'Monona', '$22,774 ', '$41,398 ', '$51,098 ', '9,243', '4,050']
# ['63', 'Hancock', '$22,713 ', '$47,318 ', '$55,922 ', '11,341', '4,741']
# ['64', 'Winnebago', '$22,684 ', '$41,871 ', '$58,700 ', '10,866', '4,597']
# ['65', 'Webster', '$22,653 ', '$40,806 ', '$54,129 ', '38,013', '15,580']
# ['66', 'Delaware', '$22,578 ', '$47,078 ', '$59,802 ', '17,764', '7,062']
# ['67', 'Des Moines', '$22,555 ', '$41,937 ', '$53,946 ', '40,325', '17,003']
# ['68', 'Franklin', '$22,507 ', '$44,863 ', '$52,917 ', '10,680', '4,332']
# ['69', 'Chickasaw', '$22,447 ', '$41,372 ', '$50,530 ', '12,439', '5,204']
# ['70', 'Howard', '$22,417 ', '$46,068 ', '$55,582 ', '9,566', '3,944']
# ['71', 'Marshall', '$22,407 ', '$45,232 ', '$55,716 ', '40,648', '15,538']
# ['72', 'Shelby', '$22,389 ', '$44,085 ', '$55,523 ', '12,167', '5,085']
# ['73', 'Wapello', '$22,376 ', '$40,093 ', '$49,309 ', '35,625', '14,552']
# ['74', 'Clayton', '$22,303 ', '$45,873 ', '$53,905 ', '18,129', '7,599']
# ['75', 'Keokuk', '$22,088 ', '$42,698 ', '$53,456 ', '10,511', '4,408']
# ['76', 'Woodbury', '$22,069 ', '$44,343 ', '$55,957 ', '102,172', '39,052']
# ['77', 'Davis', '$21,970 ', '$46,597 ', '$52,855 ', '8,753', '3,201']
# ['78', 'Ringgold', '$21,858 ', '$42,336 ', '$51,269 ', '5,131', '2,047']
# ['79', 'Cass', '$21,787 ', '$40,820 ', '$48,884 ', '13,956', '5,980']
# ['80', 'Lyon', '$21,613 ', '$49,506 ', '$57,348 ', '11,581', '4,442']
# ['81', 'Mahaska', '$21,568 ', '$45,025 ', '$57,877 ', '22,381', '8,975']
# ['82', 'Fayette', '$21,566 ', '$41,055 ', '$52,627 ', '20,880', '8,634']
# ['83', 'Floyd', '$21,416 ', '$39,467 ', '$52,808 ', '16,303', '6,886']
# ['84', 'Allamakee', '$21,349 ', '$46,623 ', '$55,926 ', '14,330', '5,845']
# ['85', 'Taylor', '$21,335 ', '$40,300 ', '$48,156 ', '6,317', '2,679']
# ['86', 'Sioux', '$21,333 ', '$51,557 ', '$60,043 ', '33,704', '11,584']
# ['87', 'Lee', '$21,324 ', '$42,444 ', '$50,630 ', '35,862', '14,610']
# ['88', 'Montgomery', '$21,301 ', '$38,624 ', '$50,595 ', '10,740', '4,558']
# ['89', 'Buena Vista', '$21,256 ', '$43,182 ', '$53,382 ', '20,260', '7,522']
# ['90', 'Monroe', '$21,228 ', '$43,245 ', '$53,052 ', '7,970', '3,213']
# ['91', 'Page', '$21,204 ', '$40,778 ', '$52,791 ', '15,932', '6,393']
# ['92', 'Crawford', '$21,181 ', '$44,377 ', '$53,794 ', '17,096', '6,413']
# ['93', 'Union', '$20,435 ', '$40,879 ', '$50,546 ', '12,534', '5,271']
# ['94', 'Louisa', '$20,367 ', '$50,457 ', '$54,923 ', '11,387', '4,346']
# ['95', 'Van Buren', '$20,209 ', '$40,073 ', '$50,064 ', '7,570', '3,108']
# ['96', 'Appanoose', '$20,084 ', '$34,689 ', '$41,250 ', '12,887', '5,627']
# ['97', 'Lucas', '$19,967 ', '$43,005 ', '$56,647 ', '8,898', '3,689']
# ['98', 'Wayne', '$18,795 ', '$35,425 ', '$44,784 ', '6,403', '2,652']
# ['99', 'Decatur', '$18,195 ', '$37,138 ', '$48,015 ', '8,457', '3,223']
# processed 102 rows

# %%
# Import to OrderedDict (explain this)
import csv

with open('Iowa 2010 Census Data Population Income.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        # When using DictReader, the first row is ignored in the for loop row count
        print(row)
        line_count += 1
    print (f'processed {line_count} rows')
# Out:
# Column names are Rank, County, Per capita income, Median household income, Median Family Income, Population, Number of households
# OrderedDict([('Rank', '1'), ('County', 'Dallas'), ('Per capita income', '$33,051 '), ('Median household income', '$67,037 '), ('Median Family Income', '$84,018 '), ('Population', '66,135'), ('Number of households', '25,240')])
# OrderedDict([('Rank', '2'), ('County', 'Dickinson'), ('Per capita income', '$29,459 '), ('Median household income', '$50,174 '), ('Median Family Income', '$59,648 '), ('Population', '16,667'), ('Number of households', '7,554')])
# OrderedDict([('Rank', '3'), ('County', 'Polk'), ('Per capita income', '$29,246 '), ('Median household income', '$56,094 '), ('Median Family Income', '$70,445 '), ('Population', '430,640'), ('Number of households', '170,197')])
# OrderedDict([('Rank', '4'), ('County', 'Warren'), ('Per capita income', '$28,798 '), ('Median household income', '$62,034 '), ('Median Family Income', '$74,042 '), ('Population', '46,225'), ('Number of households', '17,262')])
# OrderedDict([('Rank', '5'), ('County', 'Linn'), ('Per capita income', '$28,239 '), ('Median household income', '$53,674 '), ('Median Family Income', '$69,250 '), ('Population', '211,226'), ('Number of households', '86,134')])
# OrderedDict([('Rank', '6'), ('County', 'Plymouth'), ('Per capita income', '$28,060 '), ('Median household income', '$56,379 '), ('Median Family Income', '$69,261 '), ('Population', '24,986'), ('Number of households', '9,875')])
# OrderedDict([('Rank', '7'), ('County', 'Johnson'), ('Per capita income', '$28,008 '), ('Median household income', '$51,380 '), ('Median Family Income', '$74,547 '), ('Population', '130,882'), ('Number of households', '52,715')])
# OrderedDict([('Rank', '8'), ('County', 'Kossuth'), ('Per capita income', '$27,415 '), ('Median household income', '$48,277 '), ('Median Family Income', '$61,012 '), ('Population', '15,543'), ('Number of households', '6,697')])
# OrderedDict([('Rank', '9'), ('County', 'Scott'), ('Per capita income', '$27,408 '), ('Median household income', '$49,964 '), ('Median Family Income', '$64,513 '), ('Population', '165,224'), ('Number of households', '66,765')])
# OrderedDict([('Rank', ''), ('County', 'United States'), ('Per capita income', '$27,334 '), ('Median household income', '$51,914 '), ('Median Family Income', '$62,982 '), ('Population', '308,745,538'), ('Number of households', '116,716,292')])
# OrderedDict([('Rank', '10'), ('County', 'Worth'), ('Per capita income', '$27,240 '), ('Median household income', '$49,673 '), ('Median Family Income', '$56,659 '), ('Population', '7,598'), ('Number of households', '3,172')])
# OrderedDict([('Rank', '11'), ('County', 'Grundy'), ('Per capita income', '$26,916 '), ('Median household income', '$56,184 '), ('Median Family Income', '$68,151 '), ('Population', '12,453'), ('Number of households', '5,131')])
# OrderedDict([('Rank', '12'), ('County', 'Iowa County'), ('Per capita income', '$26,721 '), ('Median household income', '$56,053 '), ('Median Family Income', '$64,578 '), ('Population', '16,355'), ('Number of households', '6,677')])
# OrderedDict([('Rank', '13'), ('County', 'Guthrie'), ('Per capita income', '$26,590 '), ('Median household income', '$50,090 '), ('Median Family Income', '$61,951 '), ('Population', '10,954'), ('Number of households', '4,544')])
# OrderedDict([('Rank', '14'), ('County', 'Bremer'), ('Per capita income', '$26,522 '), ('Median household income', '$55,676 '), ('Median Family Income', '$68,602 '), ('Population', '24,276'), ('Number of households', '9,385')])
# OrderedDict([('Rank', '15'), ('County', 'Boone'), ('Per capita income', '$25,998 '), ('Median household income', '$49,578 '), ('Median Family Income', '$66,872 '), ('Population', '26,306'), ('Number of households', '10,728')])
# OrderedDict([('Rank', '16'), ('County', 'Madison'), ('Per capita income', '$25,711 '), ('Median household income', '$53,183 '), ('Median Family Income', '$67,099 '), ('Population', '15,679'), ('Number of households', '6,025')])
# OrderedDict([('Rank', '17'), ('County', 'Cerro Gordo'), ('Per capita income', '$25,463 '), ('Median household income', '$44,741 '), ('Median Family Income', '$60,148 '), ('Population', '44,151'), ('Number of households', '19,350')])
# OrderedDict([('Rank', '18'), ('County', 'Story'), ('Per capita income', '$25,450 '), ('Median household income', '$48,248 '), ('Median Family Income', '$74,278 '), ('Population', '89,542'), ('Number of households', '34,736')])
# OrderedDict([('Rank', '19'), ('County', 'Mills'), ('Per capita income', '$25,400 '), ('Median household income', '$59,481 '), ('Median Family Income', '$73,532 '), ('Population', '15,059'), ('Number of households', '5,605')])
# OrderedDict([('Rank', '20'), ('County', 'Clay'), ('Per capita income', '$25,398 '), ('Median household income', '$43,542 '), ('Median Family Income', '$56,460 '), ('Population', '16,667'), ('Number of households', '7,282')])
# OrderedDict([('Rank', ''), ('County', 'Iowa State'), ('Per capita income', '$25,335 '), ('Median household income', '$48,872 '), ('Median Family Income', '$61,804 '), ('Population', '3,046,355'), ('Number of households', '1,221,576')])
# OrderedDict([('Rank', '21'), ('County', 'Poweshiek'), ('Per capita income', '$25,218 '), ('Median household income', '$50,998 '), ('Median Family Income', '$65,744 '), ('Population', '18,914'), ('Number of households', '7,555')])
# OrderedDict([('Rank', '22'), ('County', 'Benton'), ('Per capita income', '$25,111 '), ('Median household income', '$54,726 '), ('Median Family Income', '$64,970 '), ('Population', '26,076'), ('Number of households', '10,302')])
# OrderedDict([('Rank', '23'), ('County', 'Carroll'), ('Per capita income', '$25,094 '), ('Median household income', '$47,507 '), ('Median Family Income', '$61,960 '), ('Population', '20,816'), ('Number of households', '8,683')])
# OrderedDict([('Rank', '24'), ('County', 'Dubuque'), ('Per capita income', '$25,045 '), ('Median household income', '$48,573 '), ('Median Family Income', '$61,138 '), ('Population', '93,653'), ('Number of households', '36,815')])
# OrderedDict([('Rank', '25'), ('County', "O'Brien"), ('Per capita income', '$24,771 '), ('Median household income', '$44,018 '), ('Median Family Income', '$59,391 '), ('Population', '14,398'), ('Number of households', '6,069')])
# OrderedDict([('Rank', '26'), ('County', 'Hamilton'), ('Per capita income', '$24,765 '), ('Median household income', '$46,188 '), ('Median Family Income', '$61,472 '), ('Population', '15,673'), ('Number of households', '6,540')])
# OrderedDict([('Rank', '27'), ('County', 'Cedar'), ('Per capita income', '$24,742 '), ('Median household income', '$54,321 '), ('Median Family Income', '$63,893 '), ('Population', '18,499'), ('Number of households', '7,511')])
# OrderedDict([('Rank', '28'), ('County', 'Marion'), ('Per capita income', '$24,613 '), ('Median household income', '$53,370 '), ('Median Family Income', '$65,817 '), ('Population', '33,309'), ('Number of households', '12,723')])
# OrderedDict([('Rank', '29'), ('County', 'Humboldt'), ('Per capita income', '$24,568 '), ('Median household income', '$45,282 '), ('Median Family Income', '$57,063 '), ('Population', '9,815'), ('Number of households', '4,209')])
# OrderedDict([('Rank', '30'), ('County', 'Cherokee'), ('Per capita income', '$24,507 '), ('Median household income', '$44,635 '), ('Median Family Income', '$56,696 '), ('Population', '12,072'), ('Number of households', '5,207')])
# OrderedDict([('Rank', '31'), ('County', 'Emmet'), ('Per capita income', '$24,371 '), ('Median household income', '$42,286 '), ('Median Family Income', '$55,844 '), ('Population', '10,302'), ('Number of households', '4,236')])
# OrderedDict([('Rank', '32'), ('County', 'Harrison'), ('Per capita income', '$24,221 '), ('Median household income', '$51,303 '), ('Median Family Income', '$63,283 '), ('Population', '14,928'), ('Number of households', '5,987')])
# OrderedDict([('Rank', '33'), ('County', 'Audubon'), ('Per capita income', '$24,207 '), ('Median household income', '$42,717 '), ('Median Family Income', '$58,641 '), ('Population', '6,119'), ('Number of households', '2,617')])
# OrderedDict([('Rank', '34'), ('County', 'Hardin'), ('Per capita income', '$24,154 '), ('Median household income', '$44,694 '), ('Median Family Income', '$57,612 '), ('Population', '17,534'), ('Number of households', '7,296')])
# OrderedDict([('Rank', '35'), ('County', 'Muscatine'), ('Per capita income', '$24,138 '), ('Median household income', '$51,025 '), ('Median Family Income', '$61,445 '), ('Population', '42,745'), ('Number of households', '16,412')])
# OrderedDict([('Rank', '36'), ('County', 'Butler'), ('Per capita income', '$24,030 '), ('Median household income', '$47,702 '), ('Median Family Income', '$59,641 '), ('Population', '14,867'), ('Number of households', '6,120')])
# OrderedDict([('Rank', '37'), ('County', 'Washington'), ('Per capita income', '$23,979 '), ('Median household income', '$50,710 '), ('Median Family Income', '$60,466 '), ('Population', '21,704'), ('Number of households', '8,741')])
# OrderedDict([('Rank', '38'), ('County', 'Greene'), ('Per capita income', '$23,947 '), ('Median household income', '$43,286 '), ('Median Family Income', '$60,133 '), ('Population', '9,336'), ('Number of households', '3,996')])
# OrderedDict([('Rank', '39'), ('County', 'Jefferson'), ('Per capita income', '$23,853 '), ('Median household income', '$44,167 '), ('Median Family Income', '$55,352 '), ('Population', '16,843'), ('Number of households', '6,846')])
# OrderedDict([('Rank', '40'), ('County', 'Ida'), ('Per capita income', '$23,841 '), ('Median household income', '$44,521 '), ('Median Family Income', '$58,635 '), ('Population', '7,089'), ('Number of households', '3,052')])
# OrderedDict([('Rank', '41'), ('County', 'Sac'), ('Per capita income', '$23,837 '), ('Median household income', '$42,986 '), ('Median Family Income', '$54,304 '), ('Population', '10,350'), ('Number of households', '4,482')])
# OrderedDict([('Rank', '42'), ('County', 'Pottawattamie'), ('Per capita income', '$23,782 '), ('Median household income', '$48,728 '), ('Median Family Income', '$60,354 '), ('Population', '93,158'), ('Number of households', '36,775')])
# OrderedDict([('Rank', '43'), ('County', 'Fremont'), ('Per capita income', '$23,612 '), ('Median household income', '$47,225 '), ('Median Family Income', '$59,622 '), ('Population', '7,441'), ('Number of households', '3,064')])
# OrderedDict([('Rank', '44'), ('County', 'Winneshiek'), ('Per capita income', '$23,608 '), ('Median household income', '$50,693 '), ('Median Family Income', '$61,558 '), ('Population', '21,056'), ('Number of households', '7,997')])
# OrderedDict([('Rank', '45'), ('County', 'Clinton'), ('Per capita income', '$23,573 '), ('Median household income', '$46,170 '), ('Median Family Income', '$58,681 '), ('Population', '49,116'), ('Number of households', '20,223')])
# OrderedDict([('Rank', '46'), ('County', 'Adams'), ('Per capita income', '$23,549 '), ('Median household income', '$40,368 '), ('Median Family Income', '$52,782 '), ('Population', '4,029'), ('Number of households', '1,715')])
# OrderedDict([('Rank', '47'), ('County', 'Adair'), ('Per capita income', '$23,497 '), ('Median household income', '$45,202 '), ('Median Family Income', '$57,287 '), ('Population', '7,682'), ('Number of households', '3,292')])
# OrderedDict([('Rank', '48'), ('County', 'Buchanan'), ('Per capita income', '$23,437 '), ('Median household income', '$51,961 '), ('Median Family Income', '$61,421 '), ('Population', '20,958'), ('Number of households', '8,161')])
# OrderedDict([('Rank', '49'), ('County', 'Pocahontas'), ('Per capita income', '$23,385 '), ('Median household income', '$42,105 '), ('Median Family Income', '$56,250 '), ('Population', '7,310'), ('Number of households', '3,233')])
# OrderedDict([('Rank', '50'), ('County', 'Black Hawk'), ('Per capita income', '$23,357 '), ('Median household income', '$44,178 '), ('Median Family Income', '$57,495 '), ('Population', '131,090'), ('Number of households', '52,470')])
# OrderedDict([('Rank', '51'), ('County', 'Clarke'), ('Per capita income', '$23,271 '), ('Median household income', '$45,596 '), ('Median Family Income', '$54,707 '), ('Population', '9,286'), ('Number of households', '3,701')])
# OrderedDict([('Rank', '52'), ('County', 'Jasper'), ('Per capita income', '$23,160 '), ('Median household income', '$46,396 '), ('Median Family Income', '$56,484 '), ('Population', '36,842'), ('Number of households', '14,806')])
# OrderedDict([('Rank', '53'), ('County', 'Palo Alto'), ('Per capita income', '$23,071 '), ('Median household income', '$42,800 '), ('Median Family Income', '$57,208 '), ('Population', '9,421'), ('Number of households', '3,994')])
# OrderedDict([('Rank', '54'), ('County', 'Wright'), ('Per capita income', '$23,068 '), ('Median household income', '$44,035 '), ('Median Family Income', '$53,890 '), ('Population', '13,229'), ('Number of households', '5,625')])
# OrderedDict([('Rank', '55'), ('County', 'Osceola'), ('Per capita income', '$23,063 '), ('Median household income', '$43,889 '), ('Median Family Income', '$58,286 '), ('Population', '6,462'), ('Number of households', '2,682')])
# OrderedDict([('Rank', '56'), ('County', 'Henry'), ('Per capita income', '$23,056 '), ('Median household income', '$41,983 '), ('Median Family Income', '$53,985 '), ('Population', '20,145'), ('Number of households', '7,666')])
# OrderedDict([('Rank', '57'), ('County', 'Calhoun'), ('Per capita income', '$23,049 '), ('Median household income', '$41,611 '), ('Median Family Income', '$50,037 '), ('Population', '9,670'), ('Number of households', '4,242')])
# OrderedDict([('Rank', '58'), ('County', 'Tama'), ('Per capita income', '$23,041 '), ('Median household income', '$46,288 '), ('Median Family Income', '$55,011 '), ('Population', '17,767'), ('Number of households', '6,947')])
# OrderedDict([('Rank', '59'), ('County', 'Jackson'), ('Per capita income', '$23,008 '), ('Median household income', '$42,489 '), ('Median Family Income', '$54,210 '), ('Population', '19,848'), ('Number of households', '8,289')])
# OrderedDict([('Rank', '60'), ('County', 'Jones'), ('Per capita income', '$22,873 '), ('Median household income', '$47,955 '), ('Median Family Income', '$59,167 '), ('Population', '20,638'), ('Number of households', '8,181')])
# OrderedDict([('Rank', '61'), ('County', 'Mitchell'), ('Per capita income', '$22,820 '), ('Median household income', '$48,506 '), ('Median Family Income', '$63,356 '), ('Population', '10,776'), ('Number of households', '4,395')])
# OrderedDict([('Rank', '62'), ('County', 'Monona'), ('Per capita income', '$22,774 '), ('Median household income', '$41,398 '), ('Median Family Income', '$51,098 '), ('Population', '9,243'), ('Number of households', '4,050')])
# OrderedDict([('Rank', '63'), ('County', 'Hancock'), ('Per capita income', '$22,713 '), ('Median household income', '$47,318 '), ('Median Family Income', '$55,922 '), ('Population', '11,341'), ('Number of households', '4,741')])
# OrderedDict([('Rank', '64'), ('County', 'Winnebago'), ('Per capita income', '$22,684 '), ('Median household income', '$41,871 '), ('Median Family Income', '$58,700 '), ('Population', '10,866'), ('Number of households', '4,597')])
# OrderedDict([('Rank', '65'), ('County', 'Webster'), ('Per capita income', '$22,653 '), ('Median household income', '$40,806 '), ('Median Family Income', '$54,129 '), ('Population', '38,013'), ('Number of households', '15,580')])
# OrderedDict([('Rank', '66'), ('County', 'Delaware'), ('Per capita income', '$22,578 '), ('Median household income', '$47,078 '), ('Median Family Income', '$59,802 '), ('Population', '17,764'), ('Number of households', '7,062')])
# OrderedDict([('Rank', '67'), ('County', 'Des Moines'), ('Per capita income', '$22,555 '), ('Median household income', '$41,937 '), ('Median Family Income', '$53,946 '), ('Population', '40,325'), ('Number of households', '17,003')])
# OrderedDict([('Rank', '68'), ('County', 'Franklin'), ('Per capita income', '$22,507 '), ('Median household income', '$44,863 '), ('Median Family Income', '$52,917 '), ('Population', '10,680'), ('Number of households', '4,332')])
# OrderedDict([('Rank', '69'), ('County', 'Chickasaw'), ('Per capita income', '$22,447 '), ('Median household income', '$41,372 '), ('Median Family Income', '$50,530 '), ('Population', '12,439'), ('Number of households', '5,204')])
# OrderedDict([('Rank', '70'), ('County', 'Howard'), ('Per capita income', '$22,417 '), ('Median household income', '$46,068 '), ('Median Family Income', '$55,582 '), ('Population', '9,566'), ('Number of households', '3,944')])
# OrderedDict([('Rank', '71'), ('County', 'Marshall'), ('Per capita income', '$22,407 '), ('Median household income', '$45,232 '), ('Median Family Income', '$55,716 '), ('Population', '40,648'), ('Number of households', '15,538')])
# OrderedDict([('Rank', '72'), ('County', 'Shelby'), ('Per capita income', '$22,389 '), ('Median household income', '$44,085 '), ('Median Family Income', '$55,523 '), ('Population', '12,167'), ('Number of households', '5,085')])
# OrderedDict([('Rank', '73'), ('County', 'Wapello'), ('Per capita income', '$22,376 '), ('Median household income', '$40,093 '), ('Median Family Income', '$49,309 '), ('Population', '35,625'), ('Number of households', '14,552')])
# OrderedDict([('Rank', '74'), ('County', 'Clayton'), ('Per capita income', '$22,303 '), ('Median household income', '$45,873 '), ('Median Family Income', '$53,905 '), ('Population', '18,129'), ('Number of households', '7,599')])
# OrderedDict([('Rank', '75'), ('County', 'Keokuk'), ('Per capita income', '$22,088 '), ('Median household income', '$42,698 '), ('Median Family Income', '$53,456 '), ('Population', '10,511'), ('Number of households', '4,408')])
# OrderedDict([('Rank', '76'), ('County', 'Woodbury'), ('Per capita income', '$22,069 '), ('Median household income', '$44,343 '), ('Median Family Income', '$55,957 '), ('Population', '102,172'), ('Number of households', '39,052')])
# OrderedDict([('Rank', '77'), ('County', 'Davis'), ('Per capita income', '$21,970 '), ('Median household income', '$46,597 '), ('Median Family Income', '$52,855 '), ('Population', '8,753'), ('Number of households', '3,201')])
# OrderedDict([('Rank', '78'), ('County', 'Ringgold'), ('Per capita income', '$21,858 '), ('Median household income', '$42,336 '), ('Median Family Income', '$51,269 '), ('Population', '5,131'), ('Number of households', '2,047')])
# OrderedDict([('Rank', '79'), ('County', 'Cass'), ('Per capita income', '$21,787 '), ('Median household income', '$40,820 '), ('Median Family Income', '$48,884 '), ('Population', '13,956'), ('Number of households', '5,980')])
# OrderedDict([('Rank', '80'), ('County', 'Lyon'), ('Per capita income', '$21,613 '), ('Median household income', '$49,506 '), ('Median Family Income', '$57,348 '), ('Population', '11,581'), ('Number of households', '4,442')])
# OrderedDict([('Rank', '81'), ('County', 'Mahaska'), ('Per capita income', '$21,568 '), ('Median household income', '$45,025 '), ('Median Family Income', '$57,877 '), ('Population', '22,381'), ('Number of households', '8,975')])
# OrderedDict([('Rank', '82'), ('County', 'Fayette'), ('Per capita income', '$21,566 '), ('Median household income', '$41,055 '), ('Median Family Income', '$52,627 '), ('Population', '20,880'), ('Number of households', '8,634')])
# OrderedDict([('Rank', '83'), ('County', 'Floyd'), ('Per capita income', '$21,416 '), ('Median household income', '$39,467 '), ('Median Family Income', '$52,808 '), ('Population', '16,303'), ('Number of households', '6,886')])
# OrderedDict([('Rank', '84'), ('County', 'Allamakee'), ('Per capita income', '$21,349 '), ('Median household income', '$46,623 '), ('Median Family Income', '$55,926 '), ('Population', '14,330'), ('Number of households', '5,845')])
# OrderedDict([('Rank', '85'), ('County', 'Taylor'), ('Per capita income', '$21,335 '), ('Median household income', '$40,300 '), ('Median Family Income', '$48,156 '), ('Population', '6,317'), ('Number of households', '2,679')])
# OrderedDict([('Rank', '86'), ('County', 'Sioux'), ('Per capita income', '$21,333 '), ('Median household income', '$51,557 '), ('Median Family Income', '$60,043 '), ('Population', '33,704'), ('Number of households', '11,584')])
# OrderedDict([('Rank', '87'), ('County', 'Lee'), ('Per capita income', '$21,324 '), ('Median household income', '$42,444 '), ('Median Family Income', '$50,630 '), ('Population', '35,862'), ('Number of households', '14,610')])
# OrderedDict([('Rank', '88'), ('County', 'Montgomery'), ('Per capita income', '$21,301 '), ('Median household income', '$38,624 '), ('Median Family Income', '$50,595 '), ('Population', '10,740'), ('Number of households', '4,558')])
# OrderedDict([('Rank', '89'), ('County', 'Buena Vista'), ('Per capita income', '$21,256 '), ('Median household income', '$43,182 '), ('Median Family Income', '$53,382 '), ('Population', '20,260'), ('Number of households', '7,522')])
# OrderedDict([('Rank', '90'), ('County', 'Monroe'), ('Per capita income', '$21,228 '), ('Median household income', '$43,245 '), ('Median Family Income', '$53,052 '), ('Population', '7,970'), ('Number of households', '3,213')])
# OrderedDict([('Rank', '91'), ('County', 'Page'), ('Per capita income', '$21,204 '), ('Median household income', '$40,778 '), ('Median Family Income', '$52,791 '), ('Population', '15,932'), ('Number of households', '6,393')])
# OrderedDict([('Rank', '92'), ('County', 'Crawford'), ('Per capita income', '$21,181 '), ('Median household income', '$44,377 '), ('Median Family Income', '$53,794 '), ('Population', '17,096'), ('Number of households', '6,413')])
# OrderedDict([('Rank', '93'), ('County', 'Union'), ('Per capita income', '$20,435 '), ('Median household income', '$40,879 '), ('Median Family Income', '$50,546 '), ('Population', '12,534'), ('Number of households', '5,271')])
# OrderedDict([('Rank', '94'), ('County', 'Louisa'), ('Per capita income', '$20,367 '), ('Median household income', '$50,457 '), ('Median Family Income', '$54,923 '), ('Population', '11,387'), ('Number of households', '4,346')])
# OrderedDict([('Rank', '95'), ('County', 'Van Buren'), ('Per capita income', '$20,209 '), ('Median household income', '$40,073 '), ('Median Family Income', '$50,064 '), ('Population', '7,570'), ('Number of households', '3,108')])
# OrderedDict([('Rank', '96'), ('County', 'Appanoose'), ('Per capita income', '$20,084 '), ('Median household income', '$34,689 '), ('Median Family Income', '$41,250 '), ('Population', '12,887'), ('Number of households', '5,627')])
# OrderedDict([('Rank', '97'), ('County', 'Lucas'), ('Per capita income', '$19,967 '), ('Median household income', '$43,005 '), ('Median Family Income', '$56,647 '), ('Population', '8,898'), ('Number of households', '3,689')])
# OrderedDict([('Rank', '98'), ('County', 'Wayne'), ('Per capita income', '$18,795 '), ('Median household income', '$35,425 '), ('Median Family Income', '$44,784 '), ('Population', '6,403'), ('Number of households', '2,652')])
# OrderedDict([('Rank', '99'), ('County', 'Decatur'), ('Per capita income', '$18,195 '), ('Median household income', '$37,138 '), ('Median Family Income', '$48,015 '), ('Population', '8,457'), ('Number of households', '3,223')])
# processed 102 rows

# %%
class CountyDemos:
    def __init__(self,rank,per_capita,median_house_income,median_family_income,population,num_households):
        self.rank = rank
        self.per_capita = per_capita
        self.median_house_income = median_house_income
        self.median_family_income = median_family_income
        self.population = population
        self.num_households = num_households

# %%
import collections
with open('Iowa 2010 Census Data Population Income.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    county=collections.OrderedDict()
    for row in csv_reader:
        if line_count == 0:
            line_count += 1
            continue
        county[str(row[1])] = CountyDemos(row[0],row[2],row[3],row[4],row[5],row[6])

# %%
print(county.keys())
county_list=list(county.items())
print(county_list[0])
del county["Iowa State"]
print(county_list)
# Out:
# odict_keys(['Dallas', 'Dickinson', 'Polk', 'Warren', 'Linn', 'Plymouth', 'Johnson', 'Kossuth', 'Scott', 'United States', 'Worth', 'Grundy', 'Iowa County', 'Guthrie', 'Bremer', 'Boone', 'Madison', 'Cerro Gordo', 'Story', 'Mills', 'Clay', 'Poweshiek', 'Benton', 'Carroll', 'Dubuque', "O'Brien", 'Hamilton', 'Cedar', 'Marion', 'Humboldt', 'Cherokee', 'Emmet', 'Harrison', 'Audubon', 'Hardin', 'Muscatine', 'Butler', 'Washington', 'Greene', 'Jefferson', 'Ida', 'Sac', 'Pottawattamie', 'Fremont', 'Winneshiek', 'Clinton', 'Adams', 'Adair', 'Buchanan', 'Pocahontas', 'Black Hawk', 'Clarke', 'Jasper', 'Palo Alto', 'Wright', 'Osceola', 'Henry', 'Calhoun', 'Tama', 'Jackson', 'Jones', 'Mitchell', 'Monona', 'Hancock', 'Winnebago', 'Webster', 'Delaware', 'Des Moines', 'Franklin', 'Chickasaw', 'Howard', 'Marshall', 'Shelby', 'Wapello', 'Clayton', 'Keokuk', 'Woodbury', 'Davis', 'Ringgold', 'Cass', 'Lyon', 'Mahaska', 'Fayette', 'Floyd', 'Allamakee', 'Taylor', 'Sioux', 'Lee', 'Montgomery', 'Buena Vista', 'Monroe', 'Page', 'Crawford', 'Union', 'Louisa', 'Van Buren', 'Appanoose', 'Lucas', 'Wayne', 'Decatur'])
# ('Dallas', <__main__.CountyDemos object at 0x000002F4EA101FD0>)
# [('Dallas', <__main__.CountyDemos object at 0x000002F4EA101FD0>), ('Dickinson', <__main__.CountyDemos object at 0x000002F4EA101E80>), ('Polk', <__main__.CountyDemos object at 0x000002F4EA101DA0>), ('Warren', <__main__.CountyDemos object at 0x000002F4EA101C88>), ('Linn', <__main__.CountyDemos object at 0x000002F4EA101BE0>), ('Plymouth', <__main__.CountyDemos object at 0x000002F4EA101B38>), ('Johnson', <__main__.CountyDemos object at 0x000002F4EA101A90>), ('Kossuth', <__main__.CountyDemos object at 0x000002F4EA101978>), ('Scott', <__main__.CountyDemos object at 0x000002F4EA101860>), ('United States', <__main__.CountyDemos object at 0x000002F4EA101898>), ('Worth', <__main__.CountyDemos object at 0x000002F4EA101748>), ('Grundy', <__main__.CountyDemos object at 0x000002F4EA101630>), ('Iowa County', <__main__.CountyDemos object at 0x000002F4EA101588>), ('Guthrie', <__main__.CountyDemos object at 0x000002F4EA0F0550>), ('Bremer', <__main__.CountyDemos object at 0x000002F4EA0F0AC8>), ('Boone', <__main__.CountyDemos object at 0x000002F4EA0F0160>), ('Madison', <__main__.CountyDemos object at 0x000002F4EA0F0E48>), ('Cerro Gordo', <__main__.CountyDemos object at 0x000002F4EA0F0978>), ('Story', <__main__.CountyDemos object at 0x000002F4EA0B76D8>), ('Mills', <__main__.CountyDemos object at 0x000002F4EA0ACC18>), ('Clay', <__main__.CountyDemos object at 0x000002F4EA0ACA90>), ('Poweshiek', <__main__.CountyDemos object at 0x000002F4EA0ACE10>), ('Benton', <__main__.CountyDemos object at 0x000002F4EA0AC240>), ('Carroll', <__main__.CountyDemos object at 0x000002F4EA0E0278>), ('Dubuque', <__main__.CountyDemos object at 0x000002F4EA0E0358>), ("O'Brien", <__main__.CountyDemos object at 0x000002F4EA0E04E0>), ('Hamilton', <__main__.CountyDemos object at 0x000002F4EA0E0550>), ('Cedar', <__main__.CountyDemos object at 0x000002F4EA0E0668>), ('Marion', <__main__.CountyDemos object at 0x000002F4EA0E0780>), ('Humboldt', <__main__.CountyDemos object at 0x000002F4EA0E0908>), ('Cherokee', <__main__.CountyDemos object at 0x000002F4EA0E0978>), ('Emmet', <__main__.CountyDemos object at 0x000002F4EA0E0A90>), ('Harrison', <__main__.CountyDemos object at 0x000002F4EA0E0B70>), ('Audubon', <__main__.CountyDemos object at 0x000002F4EA0E0C88>), ('Hardin', <__main__.CountyDemos object at 0x000002F4EA0E0DA0>), ('Muscatine', <__main__.CountyDemos object at 0x000002F4EA0E0E48>), ('Butler', <__main__.CountyDemos object at 0x000002F4EA0E0F60>), ('Washington', <__main__.CountyDemos object at 0x000002F4EA0FD080>), ('Greene', <__main__.CountyDemos object at 0x000002F4EA0FD1D0>), ('Jefferson', <__main__.CountyDemos object at 0x000002F4EA0FD278>), ('Ida', <__main__.CountyDemos object at 0x000002F4EA0FD3C8>), ('Sac', <__main__.CountyDemos object at 0x000002F4EA0FD4E0>), ('Pottawattamie', <__main__.CountyDemos object at 0x000002F4EA0FD588>), ('Fremont', <__main__.CountyDemos object at 0x000002F4EA0FD6D8>), ('Winneshiek', <__main__.CountyDemos object at 0x000002F4EA0FD780>), ('Clinton', <__main__.CountyDemos object at 0x000002F4EA0FD8D0>), ('Adams', <__main__.CountyDemos object at 0x000002F4EA0FD9E8>), ('Adair', <__main__.CountyDemos object at 0x000002F4EA0FDB00>), ('Buchanan', <__main__.CountyDemos object at 0x000002F4EA0FDBE0>), ('Pocahontas', <__main__.CountyDemos object at 0x000002F4EA0FDD68>), ('Black Hawk', <__main__.CountyDemos object at 0x000002F4EA0F8E10>), ('Clarke', <__main__.CountyDemos object at 0x000002F4EA0F8DD8>), ('Jasper', <__main__.CountyDemos object at 0x000002F4EA0F8EF0>), ('Palo Alto', <__main__.CountyDemos object at 0x000002F4EA0F81D0>), ('Wright', <__main__.CountyDemos object at 0x000002F4EA105208>), ('Osceola', <__main__.CountyDemos object at 0x000002F4EA105320>), ('Henry', <__main__.CountyDemos object at 0x000002F4EA105438>), ('Calhoun', <__main__.CountyDemos object at 0x000002F4EA105550>), ('Tama', <__main__.CountyDemos object at 0x000002F4EA105668>), ('Jackson', <__main__.CountyDemos object at 0x000002F4EA105780>), ('Jones', <__main__.CountyDemos object at 0 ...
